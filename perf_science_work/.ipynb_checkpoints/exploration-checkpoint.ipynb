# %%
# plotting libraries
import seaborn as sns
import matplotlib.pyplot as plt

# main
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

import statsmodels.formula.api as smf
import scipy as sp

from xgboost import XGBRegressor
import shap

# misc
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
pd.set_option('display.max_columns', 500)
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# <style>.container { width:95% !important; }</style>

# %%
data = pd.read_csv('PitcherData.csv')
data
# Out:
#      GameId     Role PitcherHandedness Delivery  ReleaseSpeed  ZoneSpeed  \
# 0    717247  Pitcher                 R       WU     92.883598  85.358162
# 1    716775  Pitcher                 R       WU     92.162498  82.678711
# 2    716858  Pitcher                 R       WU     82.715797  76.270004
# 3    717247  Pitcher                 R       WU     83.119797  75.655327
# 4    716775  Pitcher                 R       WU     82.492897  74.397636
# ..      ...      ...               ...      ...           ...        ...
# 297  717103  Pitcher                 R       WU     80.165398  73.553673
# 298  717103  Pitcher                 R       WU     90.047096  82.119057
# 299  717103  Pitcher                 R       WU     81.466599  74.968506
# 300  717103  Pitcher                 R       WU     81.094299  74.452553
# 301  717103  Pitcher                 R       WU     82.689903  76.802200
#
#      PitchVerticalApproachAngle  ReleaseExtension  ReleaseHeight  ReleaseSide  \
# ...

# %%
data.isna().sum()[data.isna().sum()>0]
# Out:
# ReleaseExtension      3
# PeakMomDL             3
# PeakMomTimeSL         3
# PeakMomTimeTorso      3
# TimeHandSeparation    3
# PitchType             4
# SpinEfficiency        5
# dtype: int64

# %%
data = data.dropna()

# %%
data.isna().sum()[data.isna().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
data['PitcherHandedness'].value_counts()
# Out:
# R    293
# Name: PitcherHandedness, dtype: int64

# %%
data['Delivery'].value_counts()
# Out:
# WU    248
# S      45
# Name: Delivery, dtype: int64

# %%
data['PitchType'].value_counts()
# Out:
# SL    134
# FB     87
# CB     61
# CH     11
# Name: PitchType, dtype: int64

# %%
data.groupby('Delivery')['PitchType'].value_counts()
# Out:
# Delivery  PitchType
# S         SL            17
#           FB            12
#           CB            10
#           CH             6
# WU        SL           117
#           FB            75
#           CB            51
#           CH             5
# Name: PitchType, dtype: int64

# %%
sns.boxplot(data['ReleaseSpeed'])
# Out:
# <Axes: >

# %%
sns.boxplot(y = 'ReleaseSpeed', x ='Delivery', data=data)
# Out:
# <Axes: xlabel='Delivery', ylabel='ReleaseSpeed'>

# %%
sns.boxplot(y = 'ReleaseSpeed', x ='PitchType', data=data)
# Out:
# <Axes: xlabel='PitchType', ylabel='ReleaseSpeed'>

# %%
data = data[data['ReleaseSpeed']<110]
sns.boxplot(y = 'ReleaseSpeed', x ='Delivery', data=data)
# Out:
# <Axes: xlabel='Delivery', ylabel='ReleaseSpeed'>

# %%
sns.boxplot(y = 'ReleaseSpeed', x ='PitchType', data=data)
# Out:
# <Axes: xlabel='PitchType', ylabel='ReleaseSpeed'>

# %%
data = data.drop(columns=['GameId','Role','PitcherHandedness','ZoneSpeed'])
data
# Out:
#     Delivery  ReleaseSpeed  PitchVerticalApproachAngle  ReleaseExtension  \
# 0         WU     92.883598                    -5.26402          7.200283
# 1         WU     92.162498                    -5.50739          7.074602
# 3         WU     83.119797                    -5.24281          6.893004
# 4         WU     82.492897                    -7.73599          6.785694
# 5         WU     83.572502                    -6.38378          6.715177
# ..       ...           ...                         ...               ...
# 297       WU     80.165398                    -8.65568          7.107855
# 298       WU     90.047096                    -3.69850          7.197643
# 299       WU     81.466599                    -5.93263          6.561353
# 300       WU     81.094299                    -5.93084          6.581911
# 301       WU     82.689903                    -6.10622          6.875325
#
#      ReleaseHeight  ReleaseSide  ArmAngleBR  ArmSlotBR  StrideLength  \
# ...

# %% [markdown]
# - pitcher release and arm data
#     - release extension, height, side
#     - arm angle, slot (check corr)
#     - stridelength, % of height, width
# - kinematic
#     - flexion angles, separation, bend angle
# - kinetic
#     - rotational velo, extension velo
# - momentum data
#     - momentum vars --> torso lfa lua...
# - timing data
#     - time to plate, all time vars

# %% [markdown]
# ## Pitcher Release and Arm data

# %% [markdown]
# based on pitcher release and arm data, these
#
# choose p>0.05 and some correlation

# %%
pitcher_vars = ['ReleaseExtension','ReleaseHeight','ReleaseSide','ArmAngleBR','ArmSlotBR','StrideLength','StrideLengthPercentHeight','StrideWidth']

for c in pitcher_vars:
    g = sns.lmplot(x=c, y='ReleaseSpeed', data=fb_data)
    def annotate(data, **kws):
        r, p = sp.stats.pearsonr(fb_data[c], fb_data['ReleaseSpeed'])
        ax = plt.gca()
        ax.text(0.6, .8, 'r={:.2f}, p={:.2g}'.format(r, p),
                transform=ax.transAxes)
    g.map_dataframe(annotate)
    plt.show()

# %% [markdown]
# ## Kinematic data

# %% [markdown]
# knee flexion at ball release is low for faster velocity which means your knee is extending more
#
# mention outliers in dlh
#
# torsosbbr mild positive corr --> could be because of arm slot relationship seen above

# %%
kinematic_vars = ['DLHipRotMin','HSSepMin', 'PARotMax', 'PAScapRetMin', 'SLKneeFlexFP', 'PAElbowFlexBR','SLKneeFlexBR', 'TorsoFBBR', 'TorsoSBBR']

for c in kinematic_vars:
    g = sns.lmplot(x=c, y='ReleaseSpeed', data=fb_data)
    def annotate(data, **kws):
        r, p = sp.stats.pearsonr(fb_data[c], fb_data['ReleaseSpeed'])
        ax = plt.gca()
        ax.text(0.6, .8, 'r={:.2f}, p={:.2g}'.format(r, p),
                transform=ax.transAxes)
    g.map_dataframe(annotate)
    plt.show()

# %% [markdown]
# ## Kinetic data

# %%
kinetic_vars = ['PeakHipsVeloX', 'PeakPitchHandVeloX','PeakPelvisRotVelo', 'PeakChestRotVelo', 'PeakElbowExtVelo', 'PeakShoulderIRVelo','PeakSLKneeExtVelo']

for c in kinetic_vars:
    g = sns.lmplot(x=c, y='ReleaseSpeed', data=fb_data)
    def annotate(data, **kws):
        r, p = sp.stats.pearsonr(fb_data[c], fb_data['ReleaseSpeed'])
        ax = plt.gca()
        ax.text(0.6, .8, 'r={:.2f}, p={:.2g}'.format(r, p),
                transform=ax.transAxes)
    g.map_dataframe(annotate)
    plt.show()

# %% [markdown]
# whenever this pitcher is planting his foot, we want him to continue with the flexion after footplant (becasue we see this pslkfv is positive, we see a higher velocity). With the flexion after footplant, eventually you want the pitcher to extend during ball release (because in the prev section we see, the more extended the knee at ball release is the better velocity
#
# basically this pitcher throws faster whenever his stride knee sinks alittle bit after foot plant to eventually be extended at ball release

# %% [markdown]
# ## Momentum data

# %%
momentum_vars = ['PeakMomDL', 'PeakMomSL', 'PeakMomTorso', 'PeakMomLFA', 'PeakMomLUA', 'PeakMomPFA', 'PeakMomPUA', 'PeakMomTotalBody']

for c in momentum_vars:
    g = sns.lmplot(x=c, y='ReleaseSpeed', data=fb_data)
    def annotate(data, **kws):
        r, p = sp.stats.pearsonr(fb_data[c], fb_data['ReleaseSpeed'])
        ax = plt.gca()
        ax.text(0.6, .8, 'r={:.2f}, p={:.2g}'.format(r, p),
                transform=ax.transAxes)
    g.map_dataframe(annotate)
    plt.show()

# %% [markdown]
# ## Timing data

# %%
fb_data.columns
# Out:
# Index(['Delivery', 'ReleaseSpeed', 'PitchVerticalApproachAngle',
#        'ReleaseExtension', 'ReleaseHeight', 'ReleaseSide', 'ArmAngleBR',
#        'ArmSlotBR', 'StrideLength', 'StrideLengthPercentHeight', 'StrideWidth',
#        'TimeToPlate', 'PeakHipsVeloX', 'PeakPitchHandVeloX', 'DLHipRotMin',
#        'HSSepMin', 'PARotMax', 'PAScapRetMin', 'SLKneeFlexFP', 'PAElbowFlexBR',
#        'SLKneeFlexBR', 'TorsoFBBR', 'TorsoSBBR', 'PeakMomDL', 'PeakMomSL',
#        'PeakMomTorso', 'PeakMomLFA', 'PeakMomLUA', 'PeakMomPFA', 'PeakMomPUA',
#        'PeakMomTotalBody', 'PeakMomTimeDL', 'PeakMomTimeSL',
#        'PeakMomTimeTorso', 'PeakMomTimeLFA', 'PeakMomTimeLUA',
#        'PeakMomTimePFA', 'PeakMomTimePUA', 'PeakMomTimeTotalBody',
#        'PeakPelvisRotVelo', 'PeakPelvisRotVeloTime', 'PeakChestRotVelo',
#        'PeakChestRotVeloTime', 'PeakElbowExtVelo', 'PeakElbowExtVeloTime',
#        'PeakShoulderIRVelo', 'PeakShoulderIRVeloTime',
# ...

# %%
timing_vars = ['PeakMomTimeDL', 'PeakMomTimeSL', 'PeakMomTimeTorso', 'PeakMomTimeLFA', 'PeakMomTimeLUA', 
               'PeakMomTimePFA', 'PeakMomTimePUA', 'PeakMomTimeTotalBody', 'PeakPelvisRotVeloTime','PeakChestRotVeloTime','PelvisChestPeakTimeDiff',
               'PeakElbowExtVeloTime','PeakShoulderIRVeloTime','ClosingTime', 'TimeFirstMove', 'TimeHandSeparation',
               'TimePeakKneeLift', 'TimeFootPlant', 'TimeMER']

for c in timing_vars:
    g = sns.lmplot(x=c, y='ReleaseSpeed', data=fb_data)
    def annotate(data, **kws):
        r, p = sp.stats.pearsonr(fb_data[c], fb_data['ReleaseSpeed'])
        ax = plt.gca()
        ax.text(0.6, .8, 'r={:.2f}, p={:.2g}'.format(r, p),
                transform=ax.transAxes)
    g.map_dataframe(annotate)
    plt.show()

# %%
fb_data.describe()
# Out:
#        ReleaseSpeed  PitchVerticalApproachAngle  ReleaseExtension  \
# count     84.000000                   84.000000         84.000000
# mean      93.713748                   -4.724685          6.989555
# std        1.790265                    1.005192          0.226495
# min       90.047096                   -7.038130          6.476258
# 25%       92.461527                   -5.488198          6.838690
# 50%       93.520451                   -4.600820          6.951185
# 75%       95.049248                   -4.131318          7.168772
# max       97.876701                   -2.765060          7.526483
#
#        ReleaseHeight  ReleaseSide  ArmAngleBR  ArmSlotBR  StrideLength  \
# count      84.000000    84.000000   84.000000  84.000000     84.000000
# mean        5.582372    -1.803461   96.780764  38.916589      6.055907
# std         0.075642     0.306155    4.428272   4.052859      0.152028
# min         5.404940    -2.320700   86.735665  30.368614      5.774588
# ...

# %%
sns.boxplot(fb_data['ReleaseSpeed'])
# Out:
# <Axes: >

# %% [markdown]
# currently just looked at timing variables given in this, but given more time i would like to look at the sequencing. Basically trying to figure out if, for example, is the timing of your chest rotational velocity peaking before timing of any other body part or the timing of your pitching motion

# %%
def get_top_corr(var,data,k):
    """
    Get the top 'k' variables that have the highest correlation with the specified 'var'.
    
    Parameters:
    - var (str): The variable/column for which the correlations are to be found.
    - k (int): The number of top correlated variables to return.
    - data (pd.DataFrame): The dataframe containing the data.
    
    Returns:
    - list: A list of tuples where each tuple contains a variable name and its correlation value with 'var'.
    """
    velo_corr = data.corr(numeric_only=True)[data.corr(numeric_only=True).index==var].to_dict(orient='index')[var]
    top_corr_keys = sorted(velo_corr, reverse=True, key=lambda dict_key: abs(velo_corr[dict_key]))[1:k+1]
    top_corr = []
    for k in top_corr_keys:
        top_corr.append((k, velo_corr[k]))
    return top_corr

get_top_corr('ReleaseSpeed',data,20)
# Out:
# [('SpinDirection', 0.7870116786554697),
#  ('PitchVerticalApproachAngle', 0.7367406978822207),
#  ('StrideWidth', -0.7134506155044857),
#  ('InducedVertBreak', 0.7020032004628227),
#  ('SpinEfficiency', 0.527999810280214),
#  ('PeakPitchHandVeloX', 0.5279612979357149),
#  ('PARotMax', 0.496811100606572),
#  ('PeakChestRotVelo', 0.48609838176321873),
#  ('SLKneeFlexBR', -0.46235618712018833),
#  ('ReleaseExtension', 0.46058815014985777),
#  ('PeakMomPUA', 0.44759638579239214),
#  ('PeakMomPFA', 0.4404265823975428),
#  ('PeakMomDL', 0.41071283765504035),
#  ('PeakMomTimePUA', 0.4042006334074793),
#  ('PeakMomLUA', 0.3998787366508144),
#  ('TimeMER', 0.38551862760537003),
#  ('HSSepMin', -0.3689983597845223),
#  ('PeakChestRotVeloTime', 0.33543059138092446),
#  ('PeakMomSL', 0.3313017276617315),
#  ('PeakMomTimeLFA', 0.3214215149348249)]

# %%
fb_data = data[data['PitchType']=='FB']
fb_data['ReleaseSpeed'].var()
# Out:
# 3.205047108581333

# %%
fb_data.shape
# Out:
# (84, 62)

# %%
fb_corr_20 = get_top_corr('ReleaseSpeed',fb_data,20)
fb_corr_20
# Out:
# [('SLKneeFlexBR', -0.7830031937312459),
#  ('ArmSlotBR', -0.7446951940922506),
#  ('ArmAngleBR', -0.6532137621695158),
#  ('PeakChestRotVelo', 0.6478176286585406),
#  ('PeakSLKneeExtVelo', -0.5971687405299773),
#  ('PeakMomPUA', 0.4822279027222014),
#  ('PeakElbowExtVeloTime', -0.47640817436915367),
#  ('SpinRate', 0.46427555831846673),
#  ('PeakPitchHandVeloX', 0.4442454441516614),
#  ('PeakPelvisRotVelo', 0.4362019419396183),
#  ('PeakChestRotVeloTime', 0.4111320847928064),
#  ('HSSepMin', -0.3831061544128458),
#  ('PeakShoulderIRVeloTime', -0.375377668257055),
#  ('InducedVertBreak', -0.36225964560127377),
#  ('PeakMomSL', 0.35364236081028766),
#  ('StrideWidth', -0.3482555407947987),
#  ('ReleaseExtension', -0.34354087338785466),
#  ('DLHipRotMin', -0.32840869127573596),
#  ('PeakElbowExtVelo', -0.3270489779156493),
#  ('TorsoSBBR', 0.2949765680923434)]

# %%
fig_fb, ax_fb = plt.subplots(10,2, figsize=(28,32))
sns.regplot(y='ReleaseSpeed', x='SLKneeFlexBR', data=fb_data, ax=ax_fb[0][0])
sns.regplot(y='ReleaseSpeed', x='ArmSlotBR', data=fb_data, ax=ax_fb[0][1])
sns.regplot(y='ReleaseSpeed', x='ArmAngleBR', data=fb_data, ax=ax_fb[1][0])
sns.regplot(y='ReleaseSpeed', x='PeakChestRotVelo', data=fb_data, ax=ax_fb[1][1])
sns.regplot(y='ReleaseSpeed', x='PeakSLKneeExtVelo', data=fb_data, ax=ax_fb[2][0])
sns.regplot(y='ReleaseSpeed', x='PeakMomPUA', data=fb_data, ax=ax_fb[2][1])
sns.regplot(y='ReleaseSpeed', x='PeakElbowExtVeloTime', data=fb_data, ax=ax_fb[3][0])
sns.regplot(y='ReleaseSpeed', x='SpinRate', data=fb_data, ax=ax_fb[3][1])
sns.regplot(y='ReleaseSpeed', x='PeakPitchHandVeloX', data=fb_data, ax=ax_fb[4][0])
sns.regplot(y='ReleaseSpeed', x='PeakPelvisRotVelo', data=fb_data, ax=ax_fb[4][1])
sns.regplot(y='ReleaseSpeed', x='PeakChestRotVeloTime', data=fb_data, ax=ax_fb[5][0])
sns.regplot(y='ReleaseSpeed', x='HSSepMin', data=fb_data, ax=ax_fb[5][1])
sns.regplot(y='ReleaseSpeed', x='PeakShoulderIRVeloTime', data=fb_data, ax=ax_fb[6][0])
sns.regplot(y='ReleaseSpeed', x='InducedVertBreak', data=fb_data, ax=ax_fb[6][1])
sns.regplot(y='ReleaseSpeed', x='PeakMomSL', data=fb_data, ax=ax_fb[7][0])
sns.regplot(y='ReleaseSpeed', x='StrideWidth', data=fb_data, ax=ax_fb[7][1])
sns.regplot(y='ReleaseSpeed', x='ReleaseExtension', data=fb_data, ax=ax_fb[8][0])
sns.regplot(y='ReleaseSpeed', x='DLHipRotMin', data=fb_data, ax=ax_fb[8][1])
sns.regplot(y='ReleaseSpeed', x='PeakElbowExtVelo', data=fb_data, ax=ax_fb[9][0])
sns.regplot(y='ReleaseSpeed', x='TorsoSBBR', data=fb_data, ax=ax_fb[9][1])

plt.show()

# %%
fb_data['Delivery'].value_counts()
# Out:
# WU    72
# S     12
# Name: Delivery, dtype: int64

# %%
[('SLKneeFlexBR', -0.7830031937312459),
 ('ArmSlotBR', -0.7446951940922506),
 ('ArmAngleBR', -0.6532137621695158),
 ('PeakChestRotVelo', 0.6478176286585406),
 ('PeakSLKneeExtVelo', -0.5971687405299773),
 ('PeakMomPUA', 0.4822279027222014),
 ('PeakElbowExtVeloTime', -0.47640817436915367),
 ('SpinRate', 0.46427555831846673),
 ('PeakPitchHandVeloX', 0.4442454441516614),
 ('PeakPelvisRotVelo', 0.4362019419396183),
 ('PeakChestRotVeloTime', 0.4111320847928064),
 ('HSSepMin', -0.3831061544128458),
 ('PeakShoulderIRVeloTime', -0.375377668257055),
 ('InducedVertBreak', -0.36225964560127377),
 ('PeakMomSL', 0.35364236081028766),
 ('StrideWidth', -0.3482555407947987),
 ('ReleaseExtension', -0.34354087338785466),
 ('DLHipRotMin', -0.32840869127573596),
 ('PeakElbowExtVelo', -0.3270489779156493),
 ('TorsoSBBR', 0.2949765680923434)]
# Out:
# [('SLKneeFlexBR', -0.7830031937312459),
#  ('ArmSlotBR', -0.7446951940922506),
#  ('ArmAngleBR', -0.6532137621695158),
#  ('PeakChestRotVelo', 0.6478176286585406),
#  ('PeakSLKneeExtVelo', -0.5971687405299773),
#  ('PeakMomPUA', 0.4822279027222014),
#  ('PeakElbowExtVeloTime', -0.47640817436915367),
#  ('SpinRate', 0.46427555831846673),
#  ('PeakPitchHandVeloX', 0.4442454441516614),
#  ('PeakPelvisRotVelo', 0.4362019419396183),
#  ('PeakChestRotVeloTime', 0.4111320847928064),
#  ('HSSepMin', -0.3831061544128458),
#  ('PeakShoulderIRVeloTime', -0.375377668257055),
#  ('InducedVertBreak', -0.36225964560127377),
#  ('PeakMomSL', 0.35364236081028766),
#  ('StrideWidth', -0.3482555407947987),
#  ('ReleaseExtension', -0.34354087338785466),
#  ('DLHipRotMin', -0.32840869127573596),
#  ('PeakElbowExtVelo', -0.3270489779156493),
#  ('TorsoSBBR', 0.2949765680923434)]

# %%
# Model Development
# Split the data into training and testing sets
features = ['SLKneeFlexBR','ArmSlotBR','ArmAngleBR','PeakChestRotVelo','PeakSLKneeExtVelo','PeakMomPUA','PeakElbowExtVeloTime','SpinRate']
X_train, X_test, y_train, y_test = train_test_split(fb_data[features], fb_data['ReleaseSpeed'], test_size=0.3, random_state=42)

# Linear Regression Model
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# Random Forest Model
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)

xgb_model = XGBRegressor(objective='reg:squarederror')
xgb_model.fit(X_train, y_train)

# Model Evaluation
# Evaluate Linear Regression Model
y_pred_lr = lr_model.predict(X_test)
mse_lr = mean_squared_error(y_test, y_pred_lr)
r2_lr = r2_score(y_test, y_pred_lr)

# Evaluate Random Forest Model
y_pred_rf = rf_model.predict(X_test)
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

y_pred_xgb = xgb_model.predict(X_test)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
r2_xgb = r2_score(y_test, y_pred_xgb)

# Print the results
print("Linear Regression MSE:", mse_lr)
print("Linear Regression R2:", r2_lr)
print("Random Forest MSE:", mse_rf)
print("Random Forest R2:", r2_rf)
print("XGBoost MSE:", mse_xgb)
print("XGBoost R2:", r2_xgb)

# Plotting feature importance (for Random Forest)
feature_importances = pd.Series(rf_model.feature_importances_, index=features)
feature_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Linear Regression MSE: 0.8194562667924876
# Linear Regression R2: 0.7223315563227641
# Random Forest MSE: 0.896138989648522
# Random Forest R2: 0.6963480192199114
# XGBoost MSE: 1.1661879723202744
# XGBoost R2: 0.6048433425535302

# %%
model = smf.ols("ReleaseSpeed ~ ArmSlotBR + PeakSLKneeExtVelo + PeakPitchHandVeloX + PeakPelvisRotVelo + PeakChestRotVeloTime + HSSepMin + StrideWidth + DLHipRotMin", data=fb_data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           ReleaseSpeed   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     46.72
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           4.40e-26
# Time:                        19:38:52   Log-Likelihood:                -92.467
# No. Observations:                  84   AIC:                             202.9
# Df Residuals:                      75   BIC:                             224.8
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ##### Removed
#
# 1. PeakMomSL
# 2. SpinRate
# 3. ArmAngleBR
# 4. TorsoSBBR
# 5. PeakMomPUA
# 6. PeakShoulderIRVeloTime
# 7. PeakElbowExtVeloTime
# 8. PeakChestRotVelo
# 9. PeakElbowExtVelo
# 10. InducedVertBreak
# 11. SLKneeFlexBR -- adding this helps R2 go to 0.85
# 12. ReleaseExtension -- adding this helps R2 go to 0.84

# %%
fig_fb2, ax_fb2 = plt.subplots(4,2, figsize=(20,15))



sns.regplot(y='ReleaseSpeed', x='PeakSLKneeExtVelo', data=fb_data, ax=ax_fb2[0][1])
sns.regplot(y='ReleaseSpeed', x='PeakPitchHandVeloX', data=fb_data, ax=ax_fb2[1][0])
sns.regplot(y='ReleaseSpeed', x='PeakPelvisRotVelo', data=fb_data, ax=ax_fb2[1][1])
sns.regplot(y='ReleaseSpeed', x='PeakChestRotVeloTime', data=fb_data, ax=ax_fb2[2][0])
sns.regplot(y='ReleaseSpeed', x='HSSepMin', data=fb_data, ax=ax_fb2[2][1])
sns.regplot(y='ReleaseSpeed', x='StrideWidth', data=fb_data, ax=ax_fb2[3][0])
sns.regplot(y='ReleaseSpeed', x='DLHipRotMin', data=fb_data, ax=ax_fb2[3][1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 6
#       4 def r2(x, y):
#       5     return stats.pearsonr(x, y)[0] ** 2
# ----> 6 sns.jointplot(y='ReleaseSpeed', x='ArmSlotBR', data=fb_data, kind="reg", stat_func=r2)
#       8 sns.regplot(y='ReleaseSpeed', x='PeakSLKneeExtVelo', data=fb_data, ax=ax_fb2[0][1])
#       9 sns.regplot(y='ReleaseSpeed', x='PeakPitchHandVeloX', data=fb_data, ax=ax_fb2[1][0])
#
# File c:\users\siddh\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py:2324, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2321     grid.plot_marginals(histplot, **marginal_kws)
#    2323     joint_kws.setdefault("color", color)
# -> 2324     grid.plot_joint(regplot, **joint_kws)
# ...

# %%
from scipy import stats
def r2(x, y):
    return stats.pearsonr(x, y)[0] ** 2
sns.jointplot(y=fb_data['ReleaseSpeed'], x=fb_data['ArmSlotBR'], kind="reg", stat_func=r2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 4
#       2 def r2(x, y):
#       3     return stats.pearsonr(x, y)[0] ** 2
# ----> 4 sns.jointplot(y=fb_data['ReleaseSpeed'], x=fb_data['ArmSlotBR'], kind="reg", stat_func=r2)
#
# File c:\users\siddh\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py:2324, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2321     grid.plot_marginals(histplot, **marginal_kws)
#    2323     joint_kws.setdefault("color", color)
# -> 2324     grid.plot_joint(regplot, **joint_kws)
#    2326 elif kind.startswith("resid"):
#    2328     joint_kws.setdefault("color", color)
#
# ...

# %%
import seaborn as sns
import scipy as sp

g = sns.lmplot(x='ArmSlotBR', y='ReleaseSpeed', data=fb_data)

def annotate(data, **kws):
    r, p = sp.stats.pearsonr(fb_data['ArmSlotBR'], fb_data['ReleaseSpeed'])
    ax = plt.gca()
    ax.text(0.6, .8, 'r={:.2f}, p={:.2g}'.format(r, p),
            transform=ax.transAxes)
    
g.map_dataframe(annotate)
plt.show()
